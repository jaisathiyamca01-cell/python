# %%
emplist=["sathiya","sabari","selva","ashok","inba"]

# %%
type(emplist)
# Out:
# list

# %%
print(emplist[:4])
# Out:
# ['sathiya', 'sabari', 'selva', 'ashok']

# %%
print(emplist[:2])
# Out:
# ['sathiya', 'sabari']

# %%
print(emplist[2:2])
# Out:
# []

# %%
emplist[-4
        :-0
       ]
# Out:
# []

# %% [markdown]
# ## To excercise Set Data Structure

# %%
empnoset={10,8,19,15,7,4,8}

# %%
type(empnoset)
# Out:
# set

# %%
print(empnoset)
# Out:
# {4, 7, 8, 10, 15, 19}

# %%
empnoset.difference()
# Out:
# {4, 7, 8, 10, 15, 19}

# %%
empnoset.add('sathita')

# %%
print(empnoset)
# Out:
# {4, 'sathita', 7, 8, 10, 15, 19}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tz/k9p47_l17gxfhb5d686djbfh0000gn/T/ipykernel_36725/885025689.py in <module>
# ----> 1 empnoset.intersection[2:]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %% [markdown]
# ## To excercise Tuple

# %%
emp_tuple=tuple()

# %%
type(emp_tuple)
# Out:
# tuple

# %%
emp_tuple=["sathiya","sabari",4,5]

# %%
print(emp_tupel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tz/k9p47_l17gxfhb5d686djbfh0000gn/T/ipykernel_36725/2725323791.py in <module>
# ----> 1 print(emp_tupel)
#
# NameError: name 'emp_tupel' is not defined

# %%
print(emp_tuple)
# Out:
# ['sathiya', 'sabari', 4, 5]

# %%
emp_tuple[1]
# Out:
# 'sabari'

# %%
emp_tuple[2]="selva"

# %%
emp_tuple
# Out:
# ['sathiya', 'sabari', 'selva', 5]

# %% [markdown]
# ## Dictionaries

# %%
emp_dic={"name":"sathiya","age":2,"dob":'25-jun-2024'}

# %%
print(emp_dic)
# Out:
# {'name': 'sathiya', 'age': 2, 'dob': '25-jun-2024'}

# %%
print(emp_dic.values)
# Out:
# <built-in method values of dict object at 0x7fa659ecf4c8>

# %%
print(emp_dic.values())
# Out:
# dict_values(['sathiya', 2, '25-jun-2024'])

# %%
print(emp_dic.keys())
# Out:
# dict_keys(['name', 'age', 'dob'])

# %%
emp_dic.items()
# Out:
# dict_items([('name', 'sathiya'), ('age', 2), ('dob', '25-jun-2024')])

# %% [markdown]
# ## To to excercise DataFrame

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
employee={"name":["sathiya","sabari","inba"],
         "id":[1001,1002,1003],
         "dob":["01-Jan-2025","10-Mar-2024","10-Aug-2025"],
         "salary":[10000,16000,12000]}

# %%
type(employee)
# Out:
# dict

# %%
empdataframe=pd.DataFrame(employee)

# %%
empdataframe
# Out:
#       name    id          dob  salary
# 0  sathiya  1001  01-Jan-2025   10000
# 1   sabari  1002  10-Mar-2024   16000
# 2     inba  1003  10-Aug-2025   12000

# %%
empdataframe.agg(['sum'])
# Out:
#                   name    id                                dob  salary
# sum  sathiyasabariinba  3006  01-Jan-202510-Mar-202410-Aug-2025   38000
